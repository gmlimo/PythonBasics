# %% [markdown]
# # Queue

# %%
class Queue:
    def __init__(self):
        self.items = []
        
    def isEmpty(self):
        return self.items == []
    
    def enqueue(self, item):
        self.items.insert(0, item)
        
    def dequeue(self):
        return self.items.pop()
    
    def size(self):
        return len(self.items)

# %%
q = Queue()

# %%
q.enqueue(3.14)

# %%
q.enqueue('Python')

# %%
q.enqueue(True)

# %%
q.dequeue()
# Out:
# 3.14

# %%
q.dequeue()
# Out:
# 'Python'

# %%
q.dequeue()
# Out:
# True

# %%
q.size()
# Out:
# 3
