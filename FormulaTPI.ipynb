# %% [markdown]
# # Python Basics on Jupyter
# Tap formula

# %%
F = float(input('Give me the machining speed in/min: '))
TPI = int(input('Now give me Tooth per Inch number: '))
S = F*TPI
print('The RPMs you need are: {}'.format(S))
